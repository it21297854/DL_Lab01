# %%
from __future__ import division, print_function, unicode_literals

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
exp_array_4x4 = np.random.exponential(scale=1.0, size=(4, 4))

# %%
exp_array_4x4
# Out:
# array([[0.43161875, 2.2772535 , 0.66909988, 3.6099802 ],
#        [0.18099077, 0.68477789, 0.55461514, 0.33598764],
#        [0.66189375, 0.60997096, 1.83349673, 0.85312702],
#        [0.90068228, 0.11799955, 0.63838634, 0.77975655]])

# %%
exp_array = np.random.exponential(scale=1.0, size=100000)
exp_array
# Out:
# array([1.36442646, 0.58067568, 2.1649474 , ..., 1.33630137, 0.4719494 ,
#        1.23964081])

# %%
uniform_array = np.random.rand(100000)
normal_array = np.random.randn(100000)

# %%
plt.figure(figsize=(10, 6))
plt.hist(exp_array, density=True, bins=100, histtype="step", color="red", label="Exponential")
plt.hist(uniform_array, density=True, bins=100, histtype="step", color="blue", label="Uniform")
plt.hist(normal_array, density=True, bins=100, histtype="step", color="green", label="Normal")

plt.axis([-3, 6, 0, 1.2])
plt.legend(loc="upper right")
plt.title("Random Distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)

# %%
z = x**2 + y**2

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')

ax.set_title('3D Plot of Z = X² + Y²')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.show()

# %%
import seaborn as sns
import pandas as pd

# %%
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv
# Read dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# %%
features = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

pearson_corr = df[features].corr(method='pearson')
spearman_corr = df[features].corr(method='spearman')

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 6))

sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', ax=ax[0], cbar_kws={'label': 'Pearson Correlation'})
ax[0].set_title('Pearson Correlation Coefficients')
ax[0].set_xticklabels(features, rotation=45)
ax[0].set_yticklabels(features, rotation=45)

sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', ax=ax[1], cbar_kws={'label': 'Spearman Correlation'})
ax[1].set_title('Spearman Correlation Coefficients')
ax[1].set_xticklabels(features, rotation=45)
ax[1].set_yticklabels(features, rotation=45)

plt.tight_layout()
plt.show()
